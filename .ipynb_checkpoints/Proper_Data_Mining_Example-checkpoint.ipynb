# %% [markdown]
# # Proper Data Mining Example
#
# This notebook demonstrates a **correct data mining workflow**:
#
# - clear objective
# - train/test split
# - model training
# - proper evaluation
#
# We use the Iris dataset for classification.

# %%
# Step 1 — Import libraries
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ## Step 2 — Load dataset

# %%
data = load_iris()
X = data.data
y = data.target

print("Dataset shape:", X.shape)

# %% [markdown]
# ## Step 3 — Train/Test Split (IMPORTANT)
#
# This step prevents overfitting and is a key difference between **proper data mining** and bad practices like data dredging.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

print("Train size:", X_train.shape)
print("Test size:", X_test.shape)

# %% [markdown]
# ## Step 4 — Train Model (KNN)

# %%
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

# %% [markdown]
# ## Step 5 — Evaluate on UNSEEN data

# %%
y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## ✅ Why This is Proper Data Mining
#
# - We used a clear task (classification)
# - We split train vs test
# - We evaluated on unseen data
# - Results are reproducible
#
# 👉 This is **not data dredging**.
